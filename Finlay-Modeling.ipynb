# %% [markdown]
# # Modeling

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
# lets bring in our final table csv first to work off
# !cp "/content/drive/MyDrive/MSBA_Capstone/msba_data/final_with_ga_updated.csv" ./

# and convert to dataframe
master = pd.read_csv('final_with_ga_updated.csv')

master.head()
# Out:
#    CUSTOMER_ID ANCHOR_DATE NEXT_ANCHOR_SAME_WD  num_add_to_cart_events  \
# 0    500245685  2025-02-17          2025-02-24                       1
# 1    500245685  2025-03-17          2025-03-24                       1
# 2    500245685  2025-04-14          2025-04-21                       1
# 3    500245685  2025-04-28          2025-05-05                       1
# 4    500245738  2024-11-20          2024-11-27                       1
#
#    total_items_added_to_cart  purchases  button_clicks  total_events  \
# 0                         37          1             41           261
# 1                         37          1             11            44
# 2                         37          1              7            55
# 3                         37          1              4            38
# 4                        397          1              1            27
#
#    ABANDONED_CART SALES_OFFICE  ... DISTRIBUTION_MODE_DESC  \
# 0               1         G111  ...                    OFS
# 1               1         G111  ...                    OFS
# 2               1         G111  ...                    OFS
# 3               1         G111  ...                    OFS
# 4               0         G111  ...                    OFS
#
#   WEEK_DAY_OF_ANCHOR_DATE WINDOW_FREQUENCY  CUTOFFTIME__C CREATED_DATE_EST  \
# 0                  Monday                7     5:00:00 PM              NaN
# 1                  Monday                7     5:00:00 PM              NaN
# 2                  Monday                7     5:00:00 PM              NaN
# 3                  Monday                7     5:00:00 PM              NaN
# 4               Wednesday                7     5:00:00 PM       2024-11-22
#
#             CREATED_DATE_UTC  ORDER_QUANTITY ORDER_TYPE  \
# 0                        NaN             NaN        NaN
# 1                        NaN             NaN        NaN
# 2                        NaN             NaN        NaN
# 3                        NaN             NaN        NaN
# 4  2024-11-22 18:46:16+00:00            13.0  MYCOKE360
#
#                                          MATERIAL_ID ORDER_EXISTS
# 0                                                NaN            0
# 1                                                NaN            0
# 2                                                NaN            0
# 3                                                NaN            0
# 4  [np.float64(129254.0), np.float64(114756.0), n...            1
#
# [5 rows x 24 columns]

# %%
# null count for columns
master.isnull().sum()
# Out:
# CUSTOMER_ID                      0
# ANCHOR_DATE                      0
# NEXT_ANCHOR_SAME_WD              0
# num_add_to_cart_events           0
# total_items_added_to_cart        0
# purchases                        0
# button_clicks                    0
# total_events                     0
# ABANDONED_CART                   0
# SALES_OFFICE                     0
# SALES_OFFICE_DESC                0
# DISTRIBUTION_MODE                0
# SHIPPING_CONDITIONS_DESC         0
# FREQUENCY_CLEAN              13107
# DISTRIBUTION_MODE_DESC           0
# WEEK_DAY_OF_ANCHOR_DATE          0
# WINDOW_FREQUENCY                 0
# CUTOFFTIME__C                    0
# CREATED_DATE_EST              2853
# CREATED_DATE_UTC              2853
# ORDER_QUANTITY                2853
# ORDER_TYPE                    2853
# MATERIAL_ID                   2853
# ORDER_EXISTS                     0
# dtype: int64

# %%
# lets see the values for frequency clean
master['SHIPPING_CONDITIONS_DESC'].value_counts()
# Out:
# SHIPPING_CONDITIONS_DESC
# 48 Hours             18620
# 24 Hours               798
# 72 Hours                44
# Dropsite 48 Hours       29
# Dropsite 24 Hours        1
# Name: count, dtype: int64

# %%
def extract_hours(desc):
  if '24' in desc:
    return 24
  elif '48' in desc:
    return 48
  elif '72' in desc:
    return 72
  else:
    return None

master['SHIPPING_CONDITIONS'] = master['SHIPPING_CONDITIONS_DESC'].apply(extract_hours)

# %%
# lets see the values for window frequency
master['WINDOW_FREQUENCY'].value_counts()
# Out:
# WINDOW_FREQUENCY
# 7     12787
# 14     3449
# 28     3233
# 21       23
# Name: count, dtype: int64

# %%
master['WEEK_DAY_OF_ANCHOR_DATE'].value_counts()
# Out:
# WEEK_DAY_OF_ANCHOR_DATE
# Wednesday    4484
# Thursday     3993
# Tuesday      3809
# Monday       3725
# Friday       3475
# Sunday          6
# Name: count, dtype: int64

# %%
# drop frequency clean
master.drop('FREQUENCY_CLEAN', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3847234546.py in <cell line: 0>()
#       1 # drop frequency clean
# ----> 2 master.drop('FREQUENCY_CLEAN', axis=1, inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['FREQUENCY_CLEAN'] not found in axis"

# %%
# row count for a customer
master[master['CUSTOMER_ID'] == 500245738].shape[0]
# Out:
# 25

# %%
# filter for customer 500245738
master[master['CUSTOMER_ID'] == 500245738 ]
# Out:
#     CUSTOMER_ID ANCHOR_DATE NEXT_ANCHOR_SAME_WD  num_add_to_cart_events  \
# 4     500245738  2024-11-20          2024-11-27                       1
# 5     500245738  2024-11-27          2024-12-04                       1
# 6     500245738  2024-12-04          2024-12-11                       3
# 7     500245738  2024-12-11          2024-12-18                       1
# 8     500245738  2024-12-18          2024-12-25                       2
# 9     500245738  2025-01-08          2025-01-15                       2
# 10    500245738  2025-01-15          2025-01-22                       1
# 11    500245738  2025-01-22          2025-01-29                       1
# 12    500245738  2025-01-29          2025-02-05                       2
# 13    500245738  2025-02-05          2025-02-12                       1
# 14    500245738  2025-02-12          2025-02-19                       4
# 15    500245738  2025-02-19          2025-02-26                       9
# 16    500245738  2025-02-26          2025-03-05                       1
# 17    500245738  2025-03-05          2025-03-12                       2
# 18    500245738  2025-03-12          2025-03-19                       2
# 19    500245738  2025-03-19          2025-03-26                       1
# 20    500245738  2025-03-26          2025-04-02                       2
# 21    500245738  2025-04-02          2025-04-09                       3
# 22    500245738  2025-04-09          2025-04-16                       1
# 23    500245738  2025-04-16          2025-04-23                       1
# 24    500245738  2025-04-23          2025-04-30                       1
# 25    500245738  2025-04-30          2025-05-07                       1
# 26    500245738  2025-05-07          2025-05-14                       1
# 27    500245738  2025-05-14          2025-05-21                       1
# 28    500245738  2025-05-21          2025-05-28                       2
#
#     total_items_added_to_cart  purchases  button_clicks  total_events  \
# 4                         397          1              1            27
# 5                         865          1              0            18
# 6                        1335          2              3            53
# 7                         757          1              0            19
# 8                         902          1              2            26
# 9                        1298          2              6            82
# 10                        721          1              0            21
# 11                        901          1              4            42
# 12                       1010          1              1            31
# 13                        829          1              0            18
# 14                        976          1              5            49
# 15                        837          2              6           107
# 16                        793          1              0            24
# 17                       1190          2              0            36
# 18                        866          2              0            24
# 19                        901          1              0            14
# 20                        794          1              1            20
# 21                        867          1              6            28
# 22                        937          1              0            14
# 23                        973          1              2            23
# 24                        865          1              0            14
# 25                       1045          1              2            18
# 26                        973          1              0            16
# 27                       1081          1              1            16
# 28                        614          1              1            23
#
#     ABANDONED_CART SALES_OFFICE  ... DISTRIBUTION_MODE_DESC  \
# 4                0         G111  ...                    OFS
# 5                0         G111  ...                    OFS
# 6                0         G111  ...                    OFS
# 7                0         G111  ...                    OFS
# 8                0         G111  ...                    OFS
# 9                0         G111  ...                    OFS
# 10               0         G111  ...                    OFS
# 11               0         G111  ...                    OFS
# 12               0         G111  ...                    OFS
# 13               0         G111  ...                    OFS
# 14               0         G111  ...                    OFS
# 15               0         G111  ...                    OFS
# 16               0         G111  ...                    OFS
# 17               0         G111  ...                    OFS
# 18               0         G111  ...                    OFS
# 19               0         G111  ...                    OFS
# 20               0         G111  ...                    OFS
# 21               0         G111  ...                    OFS
# 22               0         G111  ...                    OFS
# 23               0         G111  ...                    OFS
# 24               0         G111  ...                    OFS
# 25               0         G111  ...                    OFS
# 26               0         G111  ...                    OFS
# 27               0         G111  ...                    OFS
# 28               0         G111  ...                    OFS
#
#    WEEK_DAY_OF_ANCHOR_DATE WINDOW_FREQUENCY CUTOFFTIME__C CREATED_DATE_EST  \
# 4                Wednesday                7    5:00:00 PM       2024-11-22
# 5                Wednesday                7    5:00:00 PM       2024-11-27
# 6                Wednesday                7    5:00:00 PM       2024-12-04
# 7                Wednesday                7    5:00:00 PM       2024-12-12
# 8                Wednesday                7    5:00:00 PM       2024-12-23
# 9                Wednesday                7    5:00:00 PM       2025-01-08
# 10               Wednesday                7    5:00:00 PM       2025-01-20
# 11               Wednesday                7    5:00:00 PM       2025-01-22
# 12               Wednesday                7    5:00:00 PM       2025-01-29
# 13               Wednesday                7    5:00:00 PM       2025-02-10
# 14               Wednesday                7    5:00:00 PM       2025-02-14
# 15               Wednesday                7    5:00:00 PM       2025-02-19
# 16               Wednesday                7    5:00:00 PM       2025-03-03
# 17               Wednesday                7    5:00:00 PM       2025-03-05
# 18               Wednesday                7    5:00:00 PM       2025-03-12
# 19               Wednesday                7    5:00:00 PM       2025-03-24
# 20               Wednesday                7    5:00:00 PM       2025-03-31
# 21               Wednesday                7    5:00:00 PM       2025-04-07
# 22               Wednesday                7    5:00:00 PM       2025-04-11
# 23               Wednesday                7    5:00:00 PM       2025-04-21
# 24               Wednesday                7    5:00:00 PM       2025-04-25
# 25               Wednesday                7    5:00:00 PM       2025-05-02
# 26               Wednesday                7    5:00:00 PM       2025-05-09
# 27               Wednesday                7    5:00:00 PM       2025-05-19
# 28               Wednesday                7    5:00:00 PM       2025-05-23
#
#              CREATED_DATE_UTC ORDER_QUANTITY ORDER_TYPE  \
# 4   2024-11-22 18:46:16+00:00           13.0  MYCOKE360
# 5   2024-11-28 02:46:16+00:00           34.0  MYCOKE360
# 6   2024-12-04 22:02:03+00:00           45.0  MYCOKE360
# 7   2024-12-13 01:44:02+00:00           37.0  MYCOKE360
# 8   2024-12-23 22:36:08+00:00           33.0  MYCOKE360
# 9   2025-01-08 19:21:06+00:00           59.0  MYCOKE360
# 10  2025-01-20 22:42:02+00:00           24.0  MYCOKE360
# 11  2025-01-23 00:04:07+00:00           43.0  MYCOKE360
# 12  2025-01-29 22:02:48+00:00           37.0  MYCOKE360
# 13  2025-02-10 23:40:20+00:00           38.0  MYCOKE360
# 14  2025-02-14 21:18:04+00:00           35.0  MYCOKE360
# 15  2025-02-19 22:34:05+00:00           35.0  MYCOKE360
# 16  2025-03-03 21:42:19+00:00           30.0  MYCOKE360
# 17  2025-03-06 00:02:03+00:00           45.0  MYCOKE360
# 18  2025-03-12 20:22:40+00:00           30.0  MYCOKE360
# 19  2025-03-24 21:12:06+00:00           42.0  MYCOKE360
# 20  2025-03-31 20:36:30+00:00           29.0  MYCOKE360
# 21  2025-04-07 20:44:05+00:00           39.0  MYCOKE360
# 22  2025-04-11 20:09:13+00:00           47.0  MYCOKE360
# 23  2025-04-21 19:48:02+00:00           44.0  MYCOKE360
# 24  2025-04-25 21:46:29+00:00           31.0  MYCOKE360
# 25  2025-05-02 22:06:03+00:00           52.0  MYCOKE360
# 26  2025-05-09 23:06:13+00:00           40.0  MYCOKE360
# 27  2025-05-19 22:18:42+00:00           55.0  MYCOKE360
# 28  2025-05-23 23:10:26+00:00           25.0  MYCOKE360
#
#                                           MATERIAL_ID  ORDER_EXISTS
# 4   [np.float64(129254.0), np.float64(114756.0), n...             1
# 5   [np.float64(158490.0), np.float64(156090.0), n...             1
# 6   [np.float64(117641.0), np.float64(121751.0), n...             1
# 7   [np.float64(157128.0), np.float64(102604.0), n...             1
# 8   [np.float64(117641.0), np.float64(114756.0), n...             1
# 9   [np.float64(156090.0), np.float64(157128.0), n...             1
# 10  [np.float64(117635.0), np.float64(117641.0), n...             1
# 11  [np.float64(121750.0), np.float64(128092.0), n...             1
# 12  [np.float64(117635.0), np.float64(129254.0), n...             1
# 13  [np.float64(117603.0), np.float64(102603.0), n...             1
# 14  [np.float64(117854.0), np.float64(412090.0), n...             1
# 15  [np.float64(115583.0), np.float64(413687.0), n...             1
# 16  [np.float64(117641.0), np.float64(158779.0), n...             1
# 17  [np.float64(156089.0), np.float64(156082.0), n...             1
# 18  [np.float64(128092.0), np.float64(156089.0), n...             1
# 19  [np.float64(158779.0), np.float64(157128.0), n...             1
# 20  [np.float64(129254.0), np.float64(112259.0), n...             1
# 21  [np.float64(413687.0), np.float64(115586.0), n...             1
# 22  [np.float64(413687.0), np.float64(128092.0), n...             1
# 23  [np.float64(102604.0), np.float64(102649.0), n...             1
# 24  [np.float64(117603.0), np.float64(157128.0), n...             1
# 25  [np.float64(117635.0), np.float64(156082.0), n...             1
# 26  [np.float64(158489.0), np.float64(156089.0), n...             1
# 27  [np.float64(128092.0), np.float64(121751.0), n...             1
# 28  [np.float64(144775.0), np.float64(156082.0), n...             1
#
# [25 rows x 23 columns]

# %%
# lets check the number of abandoned carts for the customer
master[(master['CUSTOMER_ID'] == 500245738) & (master['WINDOW_FREQUENCY'] == 'Abandoned Cart')].shape[0]
# Out:
# 0

# %% [markdown]
# # Bringing in Sales/Material/Op Data

# %%
# lets bring in our final table csv first to work off
# !cp "/content/drive/MyDrive/MSBA_Capstone/msba_data/sales_material_op.csv" ./

# and convert to dataframe
smo = pd.read_csv('sales_material_op.csv')

smo.head()
# Out:
#    CUSTOMER_ID DELIVERY_ANCHOR_DAY CALLING_ANCHOR_DATE  FREQUENCY_CLEAN  \
# 0    600069597              Friday            2/5/2025                4
# 1    600069597              Friday            2/5/2025                4
# 2    600069597              Friday            2/5/2025                4
# 3    600069597              Friday            2/5/2025                4
# 4    600069597              Friday            2/5/2025                4
#
#   POSTING_DATE  MATERIAL_ID  GROSS_PROFIT_DEAD_NET  PHYSICAL_VOLUME  \
# 0     9/4/2024     129252.0                  14.88              2.0
# 1    6/12/2024     132532.0                  38.57              3.0
# 2    6/26/2024     115586.0                  30.85              4.0
# 3    6/26/2024     116307.0                  33.41              4.0
# 4    7/24/2024     132545.0                  34.40              3.0
#
#    NSI_DEAD_NET            PACK_TYPE_DESC   TRADE_MARK_DESC  \
# 0         39.84    Plastic Bottle - Other    Pete's Popcorn
# 1         60.48  Plastic Bottle - Contour  Oliver Originals
# 2         62.32              Aluminum Can     Jack's Juices
# 3         62.32              Aluminum Can      Fizz Factory
# 4         60.48    Plastic Bottle - Other      Fizz Factory
#
#         FLAVOUR_DESC                       BEV_CAT_DESC  PACK_SIZE_OZ
# 0  Vanilla Raspberry  PACKAGED WATER (PLAIN & ENRICHED)          33.8
# 1      Vanilla Latte                     CORE SPARKLING           0.0
# 2         Cappuccino                     CORE SPARKLING          12.0
# 3         Banana Nut                     CORE SPARKLING          12.0
# 4         Banana Nut                     CORE SPARKLING           0.0

# %%
# look at column names
smo.columns
# Out:
# Index(['CUSTOMER_ID', 'DELIVERY_ANCHOR_DAY', 'CALLING_ANCHOR_DATE',
#        'FREQUENCY_CLEAN', 'POSTING_DATE', 'MATERIAL_ID',
#        'GROSS_PROFIT_DEAD_NET', 'PHYSICAL_VOLUME', 'NSI_DEAD_NET',
#        'PACK_TYPE_DESC', 'TRADE_MARK_DESC', 'FLAVOUR_DESC', 'BEV_CAT_DESC',
#        'PACK_SIZE_OZ'],
#       dtype='object')

# %%
# unique calling anchor dates for customer
smo[smo['CUSTOMER_ID'] == 500245738]['CALLING_ANCHOR_DATE'].unique()
# Out:
# array(['11/18/2024'], dtype=object)

# %%
# unique delivery anchor dates for customer
smo[smo['CUSTOMER_ID'] == 500245738]['DELIVERY_ANCHOR_DAY'].unique()
# Out:
# array(['Wednesday'], dtype=object)

# %%
# row count for the customer
smo[smo['CUSTOMER_ID'] == 500245738].shape[0]
# Out:
# 485

# %%
# unique row count
unique_count = smo[smo['CUSTOMER_ID'] == 500245738]['MATERIAL_ID'].nunique()
unique_count
# Out:
# 31

# %%
# rows where customer is 500245738 and material id
smo[(smo['CUSTOMER_ID'] == 500245738) & (smo['MATERIAL_ID'] == 158489.0)]
# Out:
#         CUSTOMER_ID DELIVERY_ANCHOR_DAY CALLING_ANCHOR_DATE  FREQUENCY_CLEAN  \
# 402483    500245738           Wednesday          11/18/2024                1
# 402614    500245738           Wednesday          11/18/2024                1
# 402617    500245738           Wednesday          11/18/2024                1
# 402650    500245738           Wednesday          11/18/2024                1
# 402773    500245738           Wednesday          11/18/2024                1
# 402776    500245738           Wednesday          11/18/2024                1
# 402795    500245738           Wednesday          11/18/2024                1
#
#        POSTING_DATE  MATERIAL_ID  GROSS_PROFIT_DEAD_NET  PHYSICAL_VOLUME  \
# 402483     5/7/2025     158489.0                  14.34              2.0
# 402614    4/23/2025     158489.0                  14.34              2.0
# 402617    5/14/2025     158489.0                  14.34              2.0
# 402650   11/15/2024     158489.0                  13.90              2.0
# 402773   11/26/2024     158489.0                  13.90              2.0
# 402776   12/17/2024     158489.0                  13.90              2.0
# 402795    4/30/2025     158489.0                  14.34              2.0
#
#         NSI_DEAD_NET PACK_TYPE_DESC  TRADE_MARK_DESC    FLAVOUR_DESC  \
# 402483         46.80   Aluminum Can  Bobby's Bottles  Blueberry Acai
# 402614         46.80   Aluminum Can  Bobby's Bottles  Blueberry Acai
# 402617         46.80   Aluminum Can  Bobby's Bottles  Blueberry Acai
# 402650         45.04   Aluminum Can  Bobby's Bottles  Blueberry Acai
# 402773         45.04   Aluminum Can  Bobby's Bottles  Blueberry Acai
# 402776         45.04   Aluminum Can  Bobby's Bottles  Blueberry Acai
# 402795         46.80   Aluminum Can  Bobby's Bottles  Blueberry Acai
#
#          BEV_CAT_DESC  PACK_SIZE_OZ
# 402483  ENERGY DRINKS          16.0
# 402614  ENERGY DRINKS          16.0
# 402617  ENERGY DRINKS          16.0
# 402650  ENERGY DRINKS          16.0
# 402773  ENERGY DRINKS          16.0
# 402776  ENERGY DRINKS          16.0
# 402795  ENERGY DRINKS          16.0

# %%
# column type for posting date
smo['POSTING_DATE'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Joining the two tables

# %% [markdown]
# Turns out the join is very difficult because of all the separate rows for materials in the smo table. And then the final table structure cannot be altered too much because it would affect the abandonment column which we do not want. Therefore, we are going to aggregate the transactions per window to create some new columns and then join them back to the final table

# %%
smo['POSTING_DATE'] = pd.to_datetime(smo['POSTING_DATE'], errors = 'coerce')

# %%
# fixing the material id list
import ast

def parse_material_list(val):
    try:
        return [float(x) for x in ast.literal_eval(val)]
    except:
        return []

master['MATERIAL_LIST'] = master['MATERIAL_ID'].apply(parse_material_list)

# %%
# cross joining dataframes first
smo['_tmp'] = 1
master['_tmp'] = 1

cross = pd.merge(smo, master, on=['CUSTOMER_ID','_tmp'])

# %%
print(cross.columns)
# Out:
# Index(['CUSTOMER_ID', 'DELIVERY_ANCHOR_DAY', 'CALLING_ANCHOR_DATE',
#        'FREQUENCY_CLEAN', 'POSTING_DATE', 'MATERIAL_ID_x',
#        'GROSS_PROFIT_DEAD_NET', 'PHYSICAL_VOLUME', 'NSI_DEAD_NET',
#        'PACK_TYPE_DESC', 'TRADE_MARK_DESC', 'FLAVOUR_DESC', 'BEV_CAT_DESC',
#        'PACK_SIZE_OZ', '_tmp', 'ANCHOR_DATE', 'NEXT_ANCHOR_SAME_WD',
#        'num_add_to_cart_events', 'total_items_added_to_cart', 'purchases',
#        'button_clicks', 'total_events', 'ABANDONED_CART', 'SALES_OFFICE',
#        'SALES_OFFICE_DESC', 'DISTRIBUTION_MODE', 'SHIPPING_CONDITIONS_DESC',
#        'DISTRIBUTION_MODE_DESC', 'WEEK_DAY_OF_ANCHOR_DATE', 'WINDOW_FREQUENCY',
#        'CUTOFFTIME__C', 'CREATED_DATE_EST', 'CREATED_DATE_UTC',
#        'ORDER_QUANTITY', 'ORDER_TYPE', 'MATERIAL_ID_y', 'ORDER_EXISTS',
#        'MATERIAL_LIST'],
#       dtype='object')

# %%
# filtering by window match
window_match = cross[
    (cross['POSTING_DATE'] >= cross['ANCHOR_DATE']) &
    (cross['POSTING_DATE'] < cross['NEXT_ANCHOR_SAME_WD']) &
    (cross.apply(lambda row: row['MATERIAL_ID_x'] in row['MATERIAL_LIST'], axis=1))
]

# %% [markdown]
# Now we will calculate meaningful aggregate features by customer id and order window

# %%
aggregated = window_match.groupby(['CUSTOMER_ID', 'ANCHOR_DATE', 'NEXT_ANCHOR_SAME_WD']).agg({
    'PHYSICAL_VOLUME': 'sum',
    'NSI_DEAD_NET': 'sum',
    'GROSS_PROFIT_DEAD_NET': 'sum',
    'MATERIAL_ID_x': 'nunique'
}).rename(columns={
    'PHYSICAL_VOLUME': 'total_volume',
    'NSI_DEAD_NET': 'total_revenue',
    'GROSS_PROFIT_DEAD_NET': 'total_profit',
    'MATERIAL_ID_x': 'unique_materials'
}).reset_index()

# %% [markdown]
# Now we merge it back to the master table

# %%
final_df = master.merge(aggregated, on=['CUSTOMER_ID', 'ANCHOR_DATE', 'NEXT_ANCHOR_SAME_WD'], how='left')

# %%
final_df.head()
# Out:
#    CUSTOMER_ID ANCHOR_DATE NEXT_ANCHOR_SAME_WD  num_add_to_cart_events  \
# 0    500245685  2025-02-17          2025-02-24                       1
# 1    500245685  2025-03-17          2025-03-24                       1
# 2    500245685  2025-04-14          2025-04-21                       1
# 3    500245685  2025-04-28          2025-05-05                       1
# 4    500245738  2024-11-20          2024-11-27                       1
#
#    total_items_added_to_cart  purchases  button_clicks  total_events  \
# 0                         37          1             41           261
# 1                         37          1             11            44
# 2                         37          1              7            55
# 3                         37          1              4            38
# 4                        397          1              1            27
#
#    ABANDONED_CART SALES_OFFICE  ... ORDER_QUANTITY ORDER_TYPE  \
# 0               1         G111  ...            NaN        NaN
# 1               1         G111  ...            NaN        NaN
# 2               1         G111  ...            NaN        NaN
# 3               1         G111  ...            NaN        NaN
# 4               0         G111  ...           13.0  MYCOKE360
#
#                                          MATERIAL_ID ORDER_EXISTS  \
# 0                                                NaN            0
# 1                                                NaN            0
# 2                                                NaN            0
# 3                                                NaN            0
# 4  [np.float64(129254.0), np.float64(114756.0), n...            1
#
#   MATERIAL_LIST  _tmp total_volume total_revenue total_profit  \
# 0            []     1          NaN           NaN          NaN
# 1            []     1          NaN           NaN          NaN
# 2            []     1          NaN           NaN          NaN
# 3            []     1          NaN           NaN          NaN
# 4            []     1          NaN           NaN          NaN
#
#    unique_materials
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 29 columns]

# %%
final_df.drop(columns=['_tmp', 'MATERIAL_LIST'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1586764984.py in <cell line: 0>()
# ----> 1 final_df.drop(columns=['_tmp', 'MATERIAL_LIST'], inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['_tmp', 'MATERIAL_LIST'] not found in axis"

# %%
final_df.fillna({
    'total_volume': 0,
    'total_revenue': 0,
    'total_profit': 0,
    'unique_materials': 0
}, inplace=True)

# %% [markdown]
# This is where we run into another problem. Due to how orders and abandonment are related, many columns in our data including the sales/material columns will perfectly predict abandonment. They will be 0 or null if abandoned and have a value if not abandoned. This makes modeling on these variables basically impossible to use when modeling abandonment.

# %% [markdown]
# # Basic Logistic Regression

# %%
# logistic regression
target = 'ABANDONED_CART'

features = [
 'num_add_to_cart_events',
 'total_items_added_to_cart',
 'button_clicks',
 'total_events',
]
cats = ['DISTRIBUTION_MODE_DESC', "SALES_OFFICE_DESC", "WEEK_DAY_OF_ANCHOR_DATE", "SHIPPING_CONDITIONS"]

# %%
X = final_df[features + cats]
X = pd.get_dummies(X, columns=cats, drop_first=True)

Y = final_df[target]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=32)

model = LogisticRegression(class_weight='balanced', max_iter=1000)
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
Y_pred = model.predict(X_test)
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.58      0.70      3311
#            1       0.22      0.67      0.33       588
#
#     accuracy                           0.59      3899
#    macro avg       0.56      0.62      0.52      3899
# weighted avg       0.80      0.59      0.65      3899

# %%
#extract coefficients
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_[0]
})

coef_df = coef_df.sort_values('Coefficient', ascending=False)
coef_df
# Out:
#                             Feature  Coefficient
# 10  DISTRIBUTION_MODE_DESC_Sideload     0.872289
# 51  SALES_OFFICE_DESC_Wenatchee, WA     0.511115
# 42  SALES_OFFICE_DESC_Richfield, UT     0.465784
# 45    SALES_OFFICE_DESC_Spokane, WA     0.445558
# 18   SALES_OFFICE_DESC_Cheyenne, WY     0.443679
# ..                              ...          ...
# 44   SALES_OFFICE_DESC_Show Low, AZ    -0.390799
# 48     SALES_OFFICE_DESC_Tucson, AZ    -0.391098
# 21     SALES_OFFICE_DESC_Draper, UT    -0.429725
# 35      SALES_OFFICE_DESC_Ogden, UT    -0.618624
# 34      SALES_OFFICE_DESC_Logan, UT    -1.238641
#
# [61 rows x 2 columns]

# %%
# download file as ipynb
# !cp "/content/drive/MyDrive/Colab Notebooks/Finlay-Modeling.ipynb" ./
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/Finlay-Modeling.ipynb': No such file or directory
